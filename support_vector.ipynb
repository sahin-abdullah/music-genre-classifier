# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as pp
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.utils import parallel_backend

# %%
# feature path
path = os.path.join(os.getcwd(), 'data', 't_invar')

# %%
# load features
train = pd.read_csv(os.path.join(path, 'train.csv'), header=[0, 1, 2])
dev = pd.read_csv(os.path.join(path, 'dev.csv'), header=[0, 1, 2])
test = pd.read_csv(os.path.join(path, 'test.csv'), header=[0, 1, 2])

# %%
train.head()
# Out:
#   chroma_cens                                                              \
#           max
#             1         2         3         4         5         6         7
# 0    0.401753  0.293586  0.279790  0.254710  0.302921  0.247716  0.138682
# 1    0.209346  0.261439  0.287935  0.307697  0.296488  0.363665  0.348933
# 2    0.239863  0.031924  0.140360  0.063839  0.334769  0.739948  0.148755
# 3    0.169833  0.250565  0.292196  0.293550  0.390041  0.299625  0.314494
# 4    0.324970  0.110158  0.272007  0.416902  0.180768  0.090371  0.018058
#
#                                  ...   tonnetz                 zcr            \
#                                  ...       std                 max      mean
#           8         9        10  ...         5         6         1         1
# 0  0.323174  0.266797  0.230696  ...  0.043161  0.040683  0.055642  0.038845
# 1  0.286316  0.255562  0.201479  ...  0.043490  0.051108  0.171417  0.053200
# 2  0.255695  0.008915  0.252440  ... -0.002708  0.061586  0.058838  0.009310
# 3  0.254559  0.262152  0.236500  ...  0.080263  0.036752  0.158432  0.069996
# 4  0.320504  0.130948  0.334092  ...  0.130417  0.213566  0.092649  0.032778
#
#                                                                   target
#      median       min  kurtosis      skew       std Unnamed: 469_level_1
#           1         1         1         1         1 Unnamed: 469_level_2
# 0  0.985879  0.289423  0.051758  0.007812  0.156250                    8
# 1  0.560498  0.877931  0.165527  0.051270  0.345703                    4
# 2 -0.604153  1.129661  0.059814  0.028320  0.081055                    1
# 3  0.253030  0.068039  0.160889  0.019531  0.325195                    3
# 4  0.866067 -0.309483  0.083008  0.042969  0.167969                    1
#
# [5 rows x 470 columns]

# %%
class_names = ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
X_train = train.iloc[:, :-1].values
y_train = train.iloc[:, -1].values
X_dev = dev.iloc[:, :-1].values
y_dev = dev.iloc[:, -1].values
X_test = test.iloc[:, :-1].values
y_test = test.iloc[:, -1].values
X_test = np.concatenate((X_test, X_dev), axis=0)
y_test = np.concatenate((y_test, y_dev), axis=0)

# %%
print('Train size: {}'.format(X_train.shape))
print('Test size: {}'.format(X_test.shape))
# Out:
# Train size: (8000, 469)
# Test size: (2000, 469)

# %%
clf = SVC(decision_function_shape='ovr', class_weight='balanced', tol=1e-4, kernel='rbf', cache_size=24000)
pipe = Pipeline(steps=[('scale', StandardScaler()), ('clf', clf)])

# %%
param_grid = {'clf__C': np.logspace(-2, 0, 5)}

# %%
search = GridSearchCV(pipe, param_grid, n_jobs=-1, verbose=1, scoring='f1_macro')
search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 96 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  25 | elapsed:  1.2min remaining:   40.8s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:  1.5min finished
# GridSearchCV(estimator=Pipeline(steps=[('scale', StandardScaler()),
#                                        ('clf',
#                                         SVC(cache_size=24000,
#                                             class_weight='balanced',
#                                             tol=0.0001))]),
#              n_jobs=-1,
#              param_grid={'clf__C': array([0.01      , 0.03162278, 0.1       , 0.31622777, 1.        ])},
#              scoring='f1_macro', verbose=1)

# %%
search.best_estimator_
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('clf',
#                  SVC(cache_size=24000, class_weight='balanced', tol=0.0001))])

# %%
search.score(X_test, y_test)
# Out:
# 0.9148973084443425

# %%
train_report = pd.DataFrame(classification_report(y_train, search.predict(X_train), target_names=class_names, output_dict=True)).transpose().drop('support', axis=1)
test_report = pd.DataFrame(classification_report(y_test, search.predict(X_test), target_names=class_names, output_dict=True)).transpose().drop('support', axis=1)
report = pd.concat((train_report, test_report), axis=1)
report.columns = pd.MultiIndex.from_product([['Training Data', 'Test Data'], train_report.columns])
color_map = sns.light_palette("green", as_cmap=True)
report.style.background_gradient(cmap=color_map, low=0, high=1)
# Out:
# <style  type="text/css" >
# #T_00218f4a_4893_11eb_a24c_42010a800005row0_col0,#T_00218f4a_4893_11eb_a24c_42010a800005row5_col5,#T_00218f4a_4893_11eb_a24c_42010a800005row8_col0{
#             background-color:  #84c084;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row0_col1,#T_00218f4a_4893_11eb_a24c_42010a800005row7_col0{
#             background-color:  #92c892;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row0_col2,#T_00218f4a_4893_11eb_a24c_42010a800005row4_col0{
#             background-color:  #8ac48a;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row0_col3{
#             background-color:  #9bcc9b;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row0_col4,#T_00218f4a_4893_11eb_a24c_42010a800005row6_col4{
#             background-color:  #85c185;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row0_col5,#T_00218f4a_4893_11eb_a24c_42010a800005row5_col0{
#             background-color:  #78bb78;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row1_col0,#T_00218f4a_4893_11eb_a24c_42010a800005row1_col1,#T_00218f4a_4893_11eb_a24c_42010a800005row1_col2,#T_00218f4a_4893_11eb_a24c_42010a800005row1_col4,#T_00218f4a_4893_11eb_a24c_42010a800005row8_col3{
#             background-color:  #75b975;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row1_col3{
#             background-color:  #c0dec0;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row1_col5,#T_00218f4a_4893_11eb_a24c_42010a800005row5_col1,#T_00218f4a_4893_11eb_a24c_42010a800005row6_col5{
#             background-color:  #7cbd7c;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row2_col0{
#             background-color:  #8dc58d;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row2_col1,#T_00218f4a_4893_11eb_a24c_42010a800005row8_col1{
#             background-color:  #9ccd9c;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row2_col2{
#             background-color:  #94c994;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row2_col3,#T_00218f4a_4893_11eb_a24c_42010a800005row9_col0,#T_00218f4a_4893_11eb_a24c_42010a800005row9_col1,#T_00218f4a_4893_11eb_a24c_42010a800005row9_col2,#T_00218f4a_4893_11eb_a24c_42010a800005row9_col4,#T_00218f4a_4893_11eb_a24c_42010a800005row9_col5{
#             background-color:  #ebf3eb;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row2_col4,#T_00218f4a_4893_11eb_a24c_42010a800005row7_col2,#T_00218f4a_4893_11eb_a24c_42010a800005row10_col5,#T_00218f4a_4893_11eb_a24c_42010a800005row11_col5,#T_00218f4a_4893_11eb_a24c_42010a800005row12_col5{
#             background-color:  #90c790;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row2_col5,#T_00218f4a_4893_11eb_a24c_42010a800005row6_col3{
#             background-color:  #a5d1a5;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row3_col0{
#             background-color:  #b3d8b3;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row3_col1{
#             background-color:  #e0eee0;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row3_col2{
#             background-color:  #c8e2c8;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row3_col3{
#             background-color:  #b9dbb9;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row3_col4{
#             background-color:  #afd6af;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row3_col5{
#             background-color:  #a6d1a6;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row4_col1{
#             background-color:  #d9ead9;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row4_col2{
#             background-color:  #aed5ae;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row4_col3{
#             background-color:  #a6d2a6;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row4_col4{
#             background-color:  #93c893;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row4_col5{
#             background-color:  #88c388;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row5_col2{
#             background-color:  #7abc7a;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row5_col3,#T_00218f4a_4893_11eb_a24c_42010a800005row10_col0,#T_00218f4a_4893_11eb_a24c_42010a800005row10_col4,#T_00218f4a_4893_11eb_a24c_42010a800005row11_col0,#T_00218f4a_4893_11eb_a24c_42010a800005row11_col4,#T_00218f4a_4893_11eb_a24c_42010a800005row12_col0,#T_00218f4a_4893_11eb_a24c_42010a800005row12_col4{
#             background-color:  #99cb99;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row5_col4,#T_00218f4a_4893_11eb_a24c_42010a800005row8_col4{
#             background-color:  #96c996;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row6_col0{
#             background-color:  #bddcbd;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row6_col1{
#             background-color:  #a4d0a4;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row6_col2{
#             background-color:  #b2d7b1;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row7_col1,#T_00218f4a_4893_11eb_a24c_42010a800005row8_col2{
#             background-color:  #8fc68f;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row7_col3{
#             background-color:  #a1cfa1;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row7_col4{
#             background-color:  #8bc48b;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row7_col5{
#             background-color:  #7fbe7f;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row8_col5{
#             background-color:  #76ba76;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row9_col3{
#             background-color:  #e4f0e4;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row10_col1,#T_00218f4a_4893_11eb_a24c_42010a800005row11_col1,#T_00218f4a_4893_11eb_a24c_42010a800005row12_col1{
#             background-color:  #a8d2a8;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row10_col2,#T_00218f4a_4893_11eb_a24c_42010a800005row11_col2,#T_00218f4a_4893_11eb_a24c_42010a800005row12_col2{
#             background-color:  #a0cea0;
#             color:  #000000;
#         }#T_00218f4a_4893_11eb_a24c_42010a800005row10_col3,#T_00218f4a_4893_11eb_a24c_42010a800005row11_col3,#T_00218f4a_4893_11eb_a24c_42010a800005row12_col3{
#             background-color:  #b0d6b0;
#             color:  #000000;
#         }</style><table id="T_00218f4a_4893_11eb_a24c_42010a800005" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=3>Training Data</th>        <th class="col_heading level0 col3" colspan=3>Test Data</th>    </tr>    <tr>        <th class="blank level1" ></th>        <th class="col_heading level1 col0" >precision</th>        <th class="col_heading level1 col1" >recall</th>        <th class="col_heading level1 col2" >f1-score</th>        <th class="col_heading level1 col3" >precision</th>        <th class="col_heading level1 col4" >recall</th>        <th class="col_heading level1 col5" >f1-score</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_00218f4a_4893_11eb_a24c_42010a800005level0_row0" class="row_heading level0 row0" >blues</th>
#                         <td id="T_00218f4a_4893_11eb_a24c_42010a80

# %%
fig, axs = pp.subplots(1, 2, figsize=(15, 6), dpi=180, constrained_layout=True)
pp.rcParams.update({'font.size': 10})
cm = confusion_matrix(y_train, search.predict(X_train))
sns.heatmap(cm/(X_train.shape[0]/10) * 100, annot=True, fmt = '.1f', ax=axs[0], xticklabels=class_names, yticklabels=class_names, cmap='Blues', cbar=False)
cm = confusion_matrix(y_test, search.predict(X_test))
sns.heatmap(cm/(X_test.shape[0]/10) * 100, annot=True, fmt = '.1f', ax=axs[1], xticklabels=class_names, yticklabels=class_names, cmap='Blues', cbar=False)
for t in axs[0].texts: t.set_text(t.get_text() + "%")
for t in axs[1].texts: t.set_text(t.get_text() + "%")
axs[0].set_title('Confusion Matrix (Training)')
axs[1].set_title('Confusion Matrix (Test)')
axs[0].set_yticklabels(class_names, rotation=0)
axs[1].set_yticklabels(class_names, rotation=0);
